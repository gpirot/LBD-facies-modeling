# %% [markdown]
# ## Import necessary modules
# Dependencies:
#  - numpy
#  - pandas
#  - matplotlib

# %%
import numpy as np
import pandas as pd
import pickle
import sys
sys.path.append("../src/")
from lbd_functions import plot_elevation,plot3sections,printtimelogwithstarline,printtimelog
from lbd_functions import gen_concatenated_lenses_params,gen_facies_youth_mx,get_facies_prop
from lbd_functions import Lense, get_model_dh_litho_thickness, get_model_litho_thickness
from utils import check_plot_2_sections, get_ecdf, interp_ecdf_normalize_x, get_ecdf_area_difference
from scipy.interpolate import RegularGridInterpolator

from bayes_opt import BayesianOptimization
from bayes_opt import UtilityFunction
from bayes_opt.logger import JSONLogger
from bayes_opt.event import Events
from bayes_opt.util import load_logs

import matplotlib.pyplot as plt

top_basement_fn = '../interfaces-sediment-basement/bot_base.npy'
top_weathered_basement_fn = '../interfaces-sediment-basement/bot_delt.npy'
top_deltaic_sediments_fn = '../interfaces-sediment-basement/top_delt.npy'

bh_summary_fn = '../from-Dylan/LBW_STRATA_LOG_summary.csv'
ref_err_fn = '../from-Dylan/error-tolerance.pickle'

bo_output_json_fn = "./bo-simple-logs.json"

plot=True
Verb=True

# %%
# DEFINE RANGE FOR PARAMETERS TO EXPLORE
intensity_sand = 8.0/100
truncation_sand = 22.5/100
length_sand = 4500
thickness_sand = 4.5

intensity_clay = 7.0/100
truncation_clay = 27.5/100
length_clay = 5000
thickness_clay = 3

# Bounded region of parameter space
pbounds = {'intensity_sand': (0.05, 0.25),
           'intensity_clay': (0.05, 0.20)
          }

# %%
# DEFINE FIXED PARAMETERS
intensity_tol = 5.0/100
truncation_tol = 5.0/100
length_tol = 30/100
thickness_tol = 25/100
truncationdist = 'uniform'
lengthdist = 'uniform'
thicknessdist = 'uniform'
anisotropy = 4
anisotropy_tol = 2
anisotropydist = 'uniform'
dipdir = 90*np.pi/180 # in radians
dipdir_tol = 10*np.pi/180 # in radians
dipdirdist = 'normal'
dip = 0
dip_tol = 0
dipdist = 'normal'
facies_sand = 2
facies_clay = 3

# truncation_sand = 0.2
# truncation_clay = 0.2
# thickness_sand = 4.0
# thickness_clay = 3.0
# length_sand = 6000.0
# length_clay = 6000.0

truncation_sand = 0.25
truncation_clay = 0.25
thickness_sand = 3.8
thickness_clay = 2.2
length_sand = 7631.0
length_clay = 8074.0

printtimelogwithstarline('DEFINE PARAMETERS')
lbdseed = 12345

printtimelog('model boundaries')
xmin=5.30E5
xmax=5.45E5
ymin=7.830E6
ymax=7.842E6
zmin=-80
zmax=20
dx=dy=250
dz=1

lithocodes = [-1,0,1,2,3]
labels = ["basement","weathered-basement","intermediate","sand","clay"]
lithocolors = ["pink","lavenderblush", "sienna", "gold", "grey"]
ndhsamples = 500 # to estimate thicknesses from generated models
rng = np.random.default_rng(lbdseed)
# Out:
# **********************************************************************
# 25-Oct-2024 (16:42:40) - DEFINE PARAMETERS
# **********************************************************************
# 25-Oct-2024 (16:42:40) - model boundaries

# %%
# PROCESSING INPUT DATA
# AREA OF INTEREST GRID
aoi_nx = int((xmax-xmin)/dx)
aoi_ny = int((ymax-ymin)/dy)
aoi_nz = int((zmax-zmin)/dz)
aoi_vx = np.linspace(xmin+dx/2,xmax-dx/2,aoi_nx,endpoint=True)
aoi_vy = np.linspace(ymin+dy/2,ymax-dy/2,aoi_ny,endpoint=True)
aoi_vz = np.linspace(zmin+dz/2,zmax-dz/2,aoi_nz,endpoint=True)
aoi_xx,aoi_yy = np.meshgrid(aoi_vx,aoi_vy,indexing='xy')
aoi_pts = np.array([aoi_xx.flatten(),aoi_yy.flatten()]).T
# LOAD INTERFACES
top_basement =  np.load(top_basement_fn)
top_weathered_basement =  np.load(top_weathered_basement_fn)
top_deltaic_sediments =  np.load(top_deltaic_sediments_fn)
# GET INTERFACES DIMENSIONS
top_nx = len(np.unique(top_basement[:,0]))
top_ny = len(np.unique(top_basement[:,1]))
# GET INTERFACES X & Y COORDINATES
top_xx = np.flipud(np.reshape(top_basement[:,0],(top_ny,top_nx)))
top_yy = np.flipud(np.reshape(top_basement[:,1],(top_ny,top_nx)))
# RESHAPE INTERFACES AS 2D ARRAYS
zz_top_basement = np.flipud(np.reshape(top_basement[:,-1],(top_ny,top_nx)))
zz_top_weathered_basement = np.flipud(np.reshape(top_weathered_basement[:,-1],(top_ny,top_nx)))
zz_top_deltaic_sediments = np.flipud(np.reshape(top_deltaic_sediments[:,-1],(top_ny,top_nx)))
# ESTIMATE INTERFACES MASK
mask = zz_top_basement< zz_top_basement.max()
# APPLY MASK TO REMOVE MAX PLATEAU VALUES
zz_top_basement[mask==False]=np.nan
zz_top_weathered_basement[mask==False]=np.nan
zz_top_deltaic_sediments[mask==False]=np.nan
# ESTIMATE RESOLUTION
xc_min = top_basement[:,0].min()
xc_max = top_basement[:,0].max()
top_dx = (xc_max-xc_min)/(top_nx-1)
yc_min = top_basement[:,1].min()
yc_max = top_basement[:,1].max()
top_dy = (yc_max-yc_min)/(top_ny-1)
# INDEX OF INTERFACES IMAGES TO SELECT TO BUILD INTERPOLATOR
ix_select = (np.where(
    (top_xx >= xmin-top_dx) & (top_xx <= xmax+top_dx) &
    (top_yy >= ymin-top_dy) & (top_yy <= ymax+top_dy)
))
top_vx = np.sort(np.unique(top_xx[ix_select]))
top_vy = np.sort(np.unique(top_yy[ix_select]))
    
ori_top_basement = np.reshape(zz_top_basement[ix_select],(len(top_vy),len(top_vx)))
ori_top_weathered_basement = np.reshape(zz_top_weathered_basement[ix_select],(len(top_vy),len(top_vx)))
ori_top_deltaic_sediments = np.reshape(zz_top_deltaic_sediments[ix_select],(len(top_vy),len(top_vx)))

# DEFINE INTERPOLATORS
# # flip on y axis because of increasing vy
# data_tbt = np.flipud(ori_top_basement)
# data_twb = np.flipud(ori_top_weathered_basement)
# data_tds = np.flipud(ori_top_deltaic_sediments)

interp_top_basement = RegularGridInterpolator((top_vy, top_vx),ori_top_basement)
interp_top_weathered_basement = RegularGridInterpolator((top_vy, top_vx), ori_top_weathered_basement)
interp_top_deltaic_sediments = RegularGridInterpolator((top_vy, top_vx), ori_top_deltaic_sediments)

# INTERPOLATE INTERFACES
aoi_pts = np.array([aoi_yy.flatten(),aoi_xx.flatten()]).T    
aoi_top_basement = np.reshape(interp_top_basement(aoi_pts),(aoi_ny,aoi_nx))
aoi_top_weathered_basement = np.reshape(interp_top_weathered_basement(aoi_pts),(aoi_ny,aoi_nx))
aoi_top_deltaic_sediments = np.reshape(interp_top_deltaic_sediments(aoi_pts),(aoi_ny,aoi_nx))

# CREATE GRID
zzz,yyy,xxx = np.meshgrid(aoi_vz,aoi_vy,aoi_vx,indexing='ij')

# CREATE AQUIFER MASK
# 0 basement
# 1 aquifer domain
# np.nan above topography
tmp_twb = np.tile(np.reshape(aoi_top_weathered_basement,(1,aoi_ny,aoi_nx)),(aoi_nz,1,1))
tmp_tds = np.tile(np.reshape(aoi_top_deltaic_sediments,(1,aoi_ny,aoi_nx)),(aoi_nz,1,1))
mask_aquifer = np.zeros((aoi_nz,aoi_ny,aoi_nx))
ix_aq = np.where((zzz>=tmp_twb)&(zzz<=tmp_tds))
mask_aquifer[ix_aq] = 1
ix_air = np.where(zzz>tmp_tds)
mask_aquifer[ix_air] = np.nan

printtimelog('load LBD 1-point statistics')
f = open(ref_err_fn, 'rb')
[prop_clay_mean_p5_p95, prop_sand_mean_p5_p95, prop_inte_mean_p5_p95,
 prop_clay_err_mean_p5_p95, prop_sand_err_mean_p5_p95, prop_inte_err_mean_p5_p95,
 ecdf_clay_mean_p5_p95, ecdf_sand_mean_p5_p95, ecdf_inte_mean_p5_p95, x01_vec, thickness_lim,
 ecdf_clay_area_err_mean_p5_p95, ecdf_sand_area_err_mean_p5_p95, ecdf_inte_area_err_mean_p5_p95] = pickle.load(f)
f.close()
nbins = len(x01_vec)-1
xlim = thickness_lim[1]
# Out:
# 25-Oct-2024 (16:42:40) - load LBD 1-point statistics

# %%
# DEFINE BLACKBOX FUNCTION
# INPUT PARAMETERS
intensity_sand = 8.0/100
intensity_clay = 7.0/100

# OUTPUT: prox2lbd (1-dist2lbd)

def black_box_function(intensity_sand, intensity_clay):
    intensity_sand_tol = intensity_tol * intensity_sand
    intensity_clay_tol = intensity_tol * intensity_clay
    length_sand_tol = length_tol * length_sand
    length_clay_tol = length_tol * length_clay
    thickness_sand_tol = thickness_tol *thickness_sand 
    thickness_clay_tol = thickness_tol *thickness_clay 
    # DEFINE LENSES CLASSES
    sandLenses = Lense(intensity_sand,intensity_sand_tol,
                     truncation_sand,truncation_tol,truncationdist,
                     length_sand,length_sand_tol,lengthdist,
                     thickness_sand,thickness_sand_tol,thicknessdist,
                     anisotropy,anisotropy_tol,anisotropydist,
                     dipdir,dipdir_tol,dipdirdist,
                     dip,dip_tol,dipdist,facies_sand)
    clayLenses = Lense(intensity_clay,intensity_clay_tol,
                     truncation_clay,truncation_tol,truncationdist,
                     length_clay,length_clay_tol,lengthdist,
                     thickness_clay,thickness_clay_tol,thicknessdist,
                     anisotropy,anisotropy_tol,anisotropydist,
                     dipdir,dipdir_tol,dipdirdist,
                     dip,dip_tol,dipdist,facies_clay)

    # GENERATE TRUNCATED ELLIPSOID PARAMS FOR SAND LENSES AND CLAY LENSES
    #printtimelog('generate lense params')
    lenseClassesList = [sandLenses,clayLenses]
    Lix,Liy,Liz,Ldipdir,Ldip,La,Lb,Lc,Ltruncr,Lfacies = gen_concatenated_lenses_params(lenseClassesList,mask_aquifer,dx,dz,lbdseed+3)

    # GENERATE OBJECT BASED MODELS
    #printtimelog('generate object based model')
    facies_mx,relative_youth_mx = gen_facies_youth_mx(aoi_vx,aoi_vy,aoi_vz,Lix,Liy,Liz,Ldipdir,Ldip,La,Lb,Lc,Ltruncr,Lfacies,mask_aquifer)

    # ADD DISTINCTION BETWEEN BASEMENT AND WEATHERED BASEMENT
    #printtimelog('differentiate basement from weathered basement')
    tmp_twt = np.tile(np.reshape(aoi_top_basement,(1,aoi_ny,aoi_nx)),(aoi_nz,1,1))
    ix_bst = np.where(zzz<tmp_twt)
    facies_mx[ix_bst]=-1
    
    # COMPUTE COUNT AND PROPORTIONS PER LITHOCODE
    #printtimelog('compute proportions')
    prop = get_facies_prop(facies_mx,mask_aquifer,lithocodes[2:],labels[2:])
    #print(prop)

    # GET THICKNESSES
    #printtimelog('extract thicknesses')
    df_model_thickness = get_model_litho_thickness(facies_mx,ndhsamples,aoi_nx,aoi_ny,lithocodes,zmin,dz,rng)

    # COMPUTE EMPIRICAL CUMULATIVE DISTRIBUTION FUNCTIONS OF THICKNESS PER LITHOCODE
    #printtimelogwithstarline('COMPUTE ECDFs')
    x_clay, ecdf_clay = get_ecdf(df_model_thickness,3)
    x_sand, ecdf_sand = get_ecdf(df_model_thickness,2)
    x_inte, ecdf_inte = get_ecdf(df_model_thickness,1)

    #printtimelog('normalize ecdfs')

    ecdf01_clay = interp_ecdf_normalize_x(x_clay,ecdf_clay,xlim,x01_vec)
    ecdf01_sand = interp_ecdf_normalize_x(x_sand,ecdf_sand,xlim,x01_vec)
    ecdf01_inte = interp_ecdf_normalize_x(x_inte,ecdf_inte,xlim,x01_vec)
    
    #printtimelogwithstarline('COMPUTE DISTANCE TO LBD DATASET')
    #printtimelog('compute errors')
    err_prop_clay = (float(prop.loc[3,'proportion'])/100-prop_clay_mean_p5_p95[0]) # / prop_clay_err_mean_p5_p95[0]
    err_prop_sand = (float(prop.loc[2,'proportion'])/100-prop_sand_mean_p5_p95[0]) #/ prop_sand_err_mean_p5_p95[0]
    
    
    err_ecfd_clay,_,_,_,_,_,_ = get_ecdf_area_difference(x01_vec,ecdf_clay_mean_p5_p95[:,0],x01_vec,ecdf01_clay,nbins=nbins) #/ ecdf_clay_area_err_mean_p5_p95[0]
    err_ecfd_sand,_,_,_,_,_,_ = get_ecdf_area_difference(x01_vec,ecdf_sand_mean_p5_p95[:,0],x01_vec,ecdf01_sand,nbins=nbins) #/ ecdf_sand_area_err_mean_p5_p95[0]
    # err_ratio_ecfd_inte,_,_,_,_,_,_ = get_ecdf_area_difference(x01_vec,ecdf_inte_mean_p5_p95[:,0],x01_vec,ecdf01_inte,nbins=nbins) #/ ecdf_inte_area_err_mean_p5_p95[0]

    #printtimelog('compute distance')
    errors = np.abs(np.array([err_prop_clay,err_prop_sand,err_ecfd_clay,err_ecfd_sand]))
    #print('errors: '+str(errors))

    dist2lbd = 1 - np.prod(1-errors)**(1/len(errors))
    #print('dist2lbd: '+str(dist2lbd))    
    return 1-dist2lbd

# %%
# Test function
black_box_function(intensity_sand, intensity_clay)
# Out:
# 0.8502592372611721

# %%
logger = JSONLogger(path=bo_output_json_fn) #.json
acquisition_function = UtilityFunction(kind="ei", xi=1e-5)

bo = BayesianOptimization(
    f=black_box_function,
    pbounds=pbounds,
    verbose=2,
    random_state=12345,
)
bo.subscribe(Events.OPTIMIZATION_STEP, logger)

# %%
bo.maximize(init_points=10,n_iter=1000, acquisition_function=acquisition_function)

# %%
import json

nbo = BayesianOptimization(
    f=black_box_function,
    pbounds=pbounds,
    verbose=2,
    random_state=12345,
)
load_logs(nbo, logs=[bo_output_json_fn]); #.json

# %%
tmp = nbo.res
tmp
# Out:
# [{'target': 0.9130944582058771,
#   'params': {'intensity_clay': 0.18944241392257222,
#    'intensity_sand': 0.0974563331872679}},
#  {'target': 0.9079839727879139,
#   'params': {'intensity_clay': 0.07758782175156417,
#    'intensity_sand': 0.08068404178295596}},
#  {'target': 0.9507936147527305,
#   'params': {'intensity_clay': 0.135158754362253,
#    'intensity_sand': 0.13933170544688775}},
#  {'target': 0.9154425115954832,
#   'params': {'intensity_clay': 0.19467717796034328,
#    'intensity_sand': 0.14797656453073565}},
#  {'target': 0.9151502527285658,
#   'params': {'intensity_clay': 0.1623359956300868,
#    'intensity_sand': 0.1480354806277603}},
#  {'target': 0.949210223755584,
#   'params': {'intensity_clay': 0.1621572213906911,
#    'intensity_sand': 0.19419601041092321}},
#  {'target': 0.89063299101866,
#   'params': {'intensity_clay': 0.051258244691233024,
#    'intensity_sand': 0.06596665650465791}},
#  {'target': 0.9384590713019947,
#   'params': {'intensity_clay': 0.09480555706540725,
#    'intensity_sand': 0.1484616774623405}},
#  {'target': 0.9379463013281393,
#   'params': {'intensity_clay': 0.17147188288114024,
#    'intensity_sand': 0.18082638705864246}},
#  {'target': 0.9336970064984683,
#   'params': {'intensity_clay': 0.19469713960578955,
#    'intensity_sand': 0.15855280203799305}},
#  {'target': 0.9552931932976464,
#   'params': {'intensity_clay': 0.12348789260988466,
#    'intensity_sand': 0.14048429727154124}},
#  {'target': 0.9337965553891285,
#   'params': {'intensity_clay': 0.19468209904458394,
#    'intensity_sand': 0.15842624883117346}},
#  {'target': 0.9497309676603428,
#   'params': {'intensity_clay': 0.13516236130291853,
#    'intensity_sand': 0.13933893611820825}},
#  {'target': 0.9498718463037501,
#   'params': {'intensity_clay': 0.13508458596685913,
#    'intensity_sand': 0.139183041101969}},
#  {'target': 0.9560733953523275,
#   'params': {'intensity_clay': 0.12349357751721889,
#    'intensity_sand': 0.14033771684631768}},
#  {'target': 0.9561455768588528,
#   'params': {'intensity_clay': 0.1236415902834316,
#    'intensity_sand': 0.14040573664354683}},
#  {'target': 0.932464955492351,
#   'params': {'intensity_clay': 0.0947184436671461,
#    'intensity_sand': 0.14899102506933048}},
#  {'target': 0.9499450151121653,
#   'params': {'intensity_clay': 0.16188168789275909,
#    'intensity_sand': 0.1942079571404607}},
#  {'target': 0.9557487589282058,
#   'params': {'intensity_clay': 0.12366828123073238,
#    'intensity_sand': 0.14018742758756855}},
#  {'target': 0.9495881500021729,
#   'params': {'intensity_clay': 0.16199303360226286,
#    'intensity_sand': 0.19392737738195268}},
#  {'target': 0.9560274937476253,
#   'params': {'intensity_clay': 0.1238917635398361,
#    'intensity_sand': 0.14027471768966737}},
#  {'target': 0.9559422410309085,
#   'params': {'intensity_clay': 0.12391982086328174,
#    'intensity_sand': 0.14053341775470676}},
#  {'target': 0.9560258708532557,
#   'params': {'intensity_clay': 0.12389759735028137,
#    'intensity_sand': 0.13996639998232252}},
#  {'target': 0.9567210487012705,
#   'params': {'intensity_clay': 0.12372772104032964,
#    'intensity_sand': 0.14073890206851616}},
#  {'target': 0.9553788044941317,
#   'params': {'intensity_clay': 0.12416768720864492,
#    'intensity_sand': 0.14010031682960983}},
#  {'target': 0.9562497600287689,
#   'params': {'intensity_clay': 0.12416438897930239,
#    'intensity_sand': 0.1397779107883989}},
#  {'target': 0.9557720921747659,
#   'params': {'intensity_clay': 0.12340949777317851,
#    'intensity_sand': 0.1399357908412926}},
#  {'target': 0.9565730783870947,
#   'params': {'intensity_clay': 0.12371338441968213,
#    'intensity_sand': 0.13966700536488658}},
#  {'target': 0.9554483907365872,
#   'params': {'intensity_clay': 0.12398392321179341,
#    'intensity_sand': 0.13951288724915156}},
#  {'target': 0.9562248387452504,
#   'params': {'intensity_clay': 0.12312532072087942,
#    'intensity_sand': 0.140187891201498}},
#  {'target': 0.9560133770670577,
#   'params': {'intensity_clay': 0.1240243040059048,
#    'intensity_sand': 0.14092780218094259}},
#  {'target': 0.9560148775990018,
#   'params': {'intensity_clay': 0.12372586169016374,
#    'intensity_sand': 0.14111285365493215}},
#  {'target': 0.955002690223604,
#   'params': {'intensity_clay': 0.12333387849348089,
#    'intensity_sand': 0.13951669110162274}},
#  {'target': 0.956034454521365,
#   'params': {'intensity_clay': 0.12363980493293075,
#    'intensity_sand': 0.13928397625080574}},
#  {'target': 0.9563945963565251,
#   'params': {'intensity_clay': 0.1232955941078815,
#    'intensity_sand': 0.13907574094525277}},
#  {'target': 0.9558186400191518,
#   'params': {'intensity_clay': 0.12447437105158038,
#    'intensity_sand': 0.13949775406942833}},
#  {'target': 0.9560089719453831,
#   'params': {'intensity_clay': 0.12360156040543725,
#    'intensity_sand': 0.13886550587913585}},
#  {'target': 0.9562118740297205,
#   'params': {'intensity_clay': 0.12458852078454831,
#    'intensity_sand': 0.1398648528494372}},
#  {'target': 0.9564380382500924,
#   'params': {'intensity_clay': 0.12404617384266846,
#    'intensity_sand': 0.13902528976483997}},
#  {'target': 0.9564061676122804,
#   'params': {'intensity_clay': 0.12297494815568395,
#    'intensity_sand': 0.14059252100280265}},
#  {'target': 0.9567013575457499,
#   'params': {'intensity_clay': 0.12399413342588142,
#    'intensity_sand': 0.1386285380773003}},
#  {'target': 0.9465720584710867,
#   'params': {'intensity_clay': 0.1240689895169616,
#    'intensity_sand': 0.1413782726568723}},
#  {'target': 0.9566036735693502,
#   'params': {'intensity_clay': 0.12444884399055381,
#    'intensity_sand': 0.14051084541163333}},
#  {'target': 0.9555322567527974,
#   'params': {'intensity_clay': 0.12473068380681676,
#    'intensity_sand': 0.1402616835940521}},
#  {'target': 0.9569720717936061,
#   'params': {'intensity_clay': 0.12477798425655993,
#    'intensity_sand': 0.14073693722630737}},
#  {'target': 0.9561138483865604,
#   'params': {'intensity_clay': 0.12327423466498608,
#    'intensity_sand': 0.14097852854450602}},
#  {'target': 0.9558451825674145,
#   'params': {'intensity_clay': 0.1228183398711197,
#    'intensity_sand': 0.14100208460649047}},
#  {'target': 0.9569966069941971,
#   'params': {'intensity_clay': 0.12513087561377514,
#    'intensity_sand': 0.14054729037185332}},
#  {'target': 0.9563689041949204,
#   'params': {'intensity_clay': 0.12440444567977318,
#    'intensity_sand': 0.13879519316925823}},
#  {'target': 0.9575448635321318,
#   'params': {'intensity_clay': 0.1251822679217352,
#    'intensity_sand': 0.14009300086086382}},
#  {'target': 0.9558143779481552,
#   'params': {'intensity_clay': 0.1228172585864764,
#    'intensity_sand': 0.13980541884393094}},
#  {'target': 0.9574787923562113,
#   'params': {'intensity_clay': 0.12501426915724798,
#    'intensity_sand': 0.1396937149173471}},
#  {'target': 0.9562833314428717,
#   'params': {'intensity_clay': 0.12435354351544774,
#    'intensity_sand': 0.1383435439907708}},
#  {'target': 0.9569069457741018,
#   'params': {'intensity_clay': 0.12554318087604202,
#    'intensity_sand': 0.14031776388128817}},
#  {'target': 0.9575958895667089,
#   'params': {'intensity_clay': 0.12489840168763139,
#    'intensity_sand': 0.13923188549007762}},
#  {'target': 0.9557328752477573,
#   'params': {'intensity_clay': 0.12261566328272563,
#    'intensity_sand': 0.14027287273922606}},
#  {'target': 0.9461797217674632,
#   'params': {'intensity_clay': 0.12312091408262643,
#    'intensity_sand': 0.1414272150153169}},
#  {'target': 0.9568898370936801,
#   'params': {'intensity_clay': 0.12530728276525196,
#    'intensity_sand': 0.1394010583433573}},
#  {'target': 0.9558018576556863,
#   'params': {'intensity_clay': 0.12513295500752766,
#    'intensity_sand': 0.13888905534736207}},
#  {'target': 0.9572336507615439,
#   'params': {'intensity_clay': 0.12550154667351515,
#    'intensity_sand': 0.13984507369008964}},
#  {'target': 0.9554090596879387,
#   'params': {'intensity_clay': 0.12280082217555556,
#    'intensity_sand': 0.13925027963533743}},
#  {'target': 0.9562435481896083,
#   'params': {'intensity_clay': 0.12389946543968892,
#    'intensity_sand': 0.13815537375515136}},
#  {'target': 0.9566417785531253,
#   'params': {'intensity_clay': 0.1254765232642385,
#    'intensity_sand': 0.14084189488212648}},
#  {'target': 0.9571746698494441,
#   'params': {'intensity_clay': 0.1256753642171372,
#    'intensity_sand': 0.13908065000794426}},
#  {'target': 0.9565605640458577,
#   'params': {'intensity_clay': 0.12590161193136992,
#    'intensity_sand': 0.14065272425110908}},
#  {'target': 0.9432540383170145,
#   'params': {'intensity_clay': 0.12246223506479717,
#    'intensity_sand': 0.140734143903315}},
#  {'target': 0.9565273762331267,
#   'params': {'intensity_clay': 0.12580539900003349,
#    'intensity_sand': 0.13947967866194616}},
#  {'target': 0.9557869631784094,
#   'params': {'intensity_clay': 0.12426034945746779,
#    'intensity_sand': 0.13785044504368163}},
#  {'target': 0.9573954514956499,
#   'params': {'intensity_clay': 0.1250810094925362,
#    'intensity_sand': 0.14106146080929732}},
#  {'target': 0.956762614465449,
#   'params': {'intensity_clay': 0.12611958292071812,
#    'intensity_sand': 0.13909862809197562}},
#  {'target': 0.9564751161753313,
#   'params': {'intensity_clay': 0.12303422435893448,
#    'intensity_sand': 0.13867037108793515}},
#  {'target': 0.9578344257274701,
#   'params': {'intensity_clay': 0.12584734454251387,
#    'intensity_sand': 0.14115710325141287}},
#  {'target': 0.9572087571034786,
#   'params': {'intensity_clay': 0.12622210338844003,
#    'intensity_sand': 0.14101765916431247}},
#  {'target': 0.9567160554742347,
#   'params': {'intensity_clay': 0.12590370817961974,
#    'intensity_sand': 0.1386774003107565}},
#  {'target': 0.9567491166943256,
#   'params': {'intensity_clay': 0.1263965106154245,
#    'intensity_sand': 0.14055839976153645}},
#  {'target': 0.9566446726163417,
#   'params': {'intensity_clay': 0.1234169118722326,
#    'intensity_sand': 0.13837199111326914}},
#  {'target': 0.9568203781360001,
#   'params': {'intensity_clay': 0.12637903095182307,
#    'intensity_sand': 0.13867770528951326}},
#  {'target': 0.9574838803832619,
#   'params': {'intensity_clay': 0.12663527083198822,
#    'intensity_sand': 0.13907978201718418}},
#  {'target': 0.9556803071110325,
#   'params': {'intensity_clay': 0.12297750863079242,
#    'intensity_sand': 0.13815069181386141}},
#  {'target': 0.9558187043919959,
#   'params': {'intensity_clay': 0.12253565051561985,
#    'intensity_sand': 0.13859135651838192}},
#  {'target': 0.957452227898023,
#   'params': {'intensity_clay': 0.12643169128133608,
#    'intensity_sand': 0.1395246737729347}},
#  {'target': 0.9569584377979297,
#   'params': {'intensity_clay': 0.12609741627280807,
#    'intensity_sand': 0.140017299033975}},
#  {'target': 0.9565825696208609,
#   'params': {'intensity_clay': 0.12546253853132128,
#    'intensity_sand': 0.13843847520510436}},
#  {'target': 0.956526688279748,
#   'params': {'intensity_clay': 0.12657412261496193,
#    'intensity_sand': 0.14001240051792432}},
#  {'target': 0.9556707185016146,
#   'params': {'intensity_clay': 0.1254432390363049,
#    'intensity_sand': 0.1413618936397787}},
#  {'target': 0.9570367447543756,
#   'params': {'intensity_clay': 0.12491992728560779,
#    'intensity_sand': 0.13831803662754838}},
#  {'target': 0.9573284064776045,
#   'params': {'intensity_clay': 0.12689739825958596,
#    'intensity_sand': 0.14048512551275136}},
#  {'target': 0.9568645591865423,
#   'params': {'intensity_clay': 0.12688642422702837,
#    'intensity_sand': 0.13951560747081507}},
#  {'target': 0.9565768332508378,
#   'params': {'intensity_clay': 0.12709020880870794,
#    'intensity_sand': 0.14005064617711638}},
#  {'target': 0.9581581367977221,
#   'params': {'intensity_clay': 0.12736482972656626,
#    'intensity_sand': 0.14049358584365207}},
#  {'target': 0.9440463057751941,
#   'params': {'intensity_clay': 0.12230684643661156,
#    'intensity_sand': 0.13978856051023247}},
#  {'target': 0.9568310211183169,
#   'params': {'intensity_clay': 0.12716234760880712,
#    'intensity_sand': 0.14086226113044656}},
#  {'target': 0.9575252998743967,
#   'params': {'intensity_clay': 0.12765750780093224,
#    'intensity_sand': 0.14080707128230308}},
#  {'target': 0.9563105862222431,
#   'params': {'intensity_clay': 0.12483996165381642,
#    'intensity_sand': 0.13785868336253698}},
#  {'target': 0.9568742198248462,
#   'params': {'intensity_clay': 0.12778168818787577,
#    'intensity_sand': 0.1403645830050577}},
#  {'target': 0.9565195757135111,
#   'params': {'intensity_clay': 0.12756520176757416,
#    'intensity_sand': 0.13991128105717823}},
#  {'target': 0.9571694443703268,
#   'params': {'intensity_clay': 0.12531729991715768,
#    'intensity_sand': 0.13797640882796192}},
#  {'target': 0.9555634084331764,
#   'params': {'intensity_clay': 0.12347203984076142,
#    'intensity_sand': 0.13781476434355272}},
#  {'target': 0.9556551093141625,
#   'params': {'intensity_clay': 0.1261256990828244,
#    'intensity_sand': 0.14150597739132656}},
#  {'target': 0.9399684815357954,
#   'params': {'intensity_clay': 0.12525994189472206,
#    'intensity_sand': 0.13747876428297262}},
#  {'target': 0.9582429236061365,
#   'params': {'intensity_clay': 0.1271217158114257,
#    'intensity_sand': 0.13904550048741798}},
#  {'target': 0.9571996237597636,
#   'params': {'intensity_clay': 0.12737684287747125,
#    'intensity_sand': 0.1393798009759902}},
#  {'target': 0.9578852774302259,
#   'params': {'intensity_clay': 0.12814138946470113,
#    'intensity_sand': 0.14076053975306874}},
#  {'target': 0.9571785501065422,
#   'params': {'intensity_clay': 0.1258350168551018,
#    'intensity_sand': 0.13815329280916097}},
#  {'target': 0.9574789234016275,
#   'params': {'intensity_clay': 0.12800491497255054,
#    'intensity_sand': 0.1411623144653288}},
#  {'target': 0.9574945415425488,
#   'params': {'intensity_clay': 0.12789658618134875,
#    'intensity_sand': 0.13943738068600706}},
#  {'target': 0.9577162070630946,
#   'params': {'intensity_clay': 0.126908541947734,
#    'intensity_sand': 0.13866768070754504}},
#  {'target': 0.95789420013221,
#   'params': {'intensity_clay': 0.12760765770960203,
#    'intensity_sand': 0.13896776122961815}},
#  {'target': 0.9575031224581194,
#   'params': {'intensity_clay': 0.12813008969531187,
#    'intensity_sand': 0.13989965872631918}},
#  {'target': 0.957597232056107,
#   'params': {'intensity_clay': 0.1280832455305009,
#    'intensity_sand': 0.13899577410138947}},
#  {'target': 0.9572217805232349,
#   'params': {'intensity_clay': 0.1278266943372041,
#    'intensity_sand': 0.13856613621572983}},
#  {'target': 0.9572672452091818,
#   'params': {'intensity_clay': 0.12846412081140188,
#    'intensity_sand': 0.1410793839584356}},
#  {'target': 0.9572450232436389,
#   'params': {'intensity_clay': 0.12840014375329997,
#    'intensity_sand': 0.14034251477453874}},
#  {'target': 0.9576074499452857,
#   'params': {'intensity_clay': 0.12734428176149537,
#    'intensity_sand': 0.13861541405309136}},
#  {'target': 0.957367447651967,
#   'params': {'intensity_clay': 0.12838348647854594,
#    'intensity_sand': 0.1394550486126568}},
#  {'target': 0.9574419204920186,
#   'params': {'intensity_clay': 0.12861974263662743,
#    'intensity_sand': 0.1398906806713048}},
#  {'target': 0.956955039111574,
#   'params': {'intensity_clay': 0.12669444452789244,
#    'intensity_sand': 0.14100293259254396}},
#  {'target': 0.9572222815306921,
#   'params': {'intensity_clay': 0.12644445716559619,
#    'intensity_sand': 0.13815780560561924}},
#  {'target': 0.9513732136599555,
#   'params': {'intensity_clay': 0.1274981233551998,
#    'intensity_sand': 0.1413368264210767}},
#  {'target': 0.9577394488052468,
#   'params': {'intensity_clay': 0.12697253565782604,
#    'intensity_sand': 0.13817888132317482}},
#  {'target': 0.9573768172051134,
#   'params': {'intensity_clay': 0.12890086918948299,
#    'intensity_sand': 0.13945010125801738}},
#  {'target': 0.957988252310997,
#   'params': {'intensity_clay': 0.12863516038918918,
#    'intensity_sand': 0.13900443480948793}},
#  {'target': 0.9531532332900643,
#   'params': {'intensity_clay': 0.12835089033574634,
#    'intensity_sand': 0.14154786438564}},
#  {'target': 0.9573624951199962,
#   'params': {'intensity_clay': 0.12675634323941393,
#    'intensity_sand': 0.13775405430971535}},
#  {'target': 0.9569453937400666,
#   'params': {'intensity_clay': 0.12745936189187218,
#    'intensity_sand': 0.1380767997773977}},
#  {'target': 0.9568671536922566,
#   'params': {'intensity_clay': 0.12875999015917367,
#    'intensity_sand': 0.14067002390485994}},
#  {'target': 0.9577582301614931,
#   'params': {'intensity_clay': 0.1280577478276115,
#    'intensity_sand': 0.13809004650924214}},
#  {'target': 0.9573688944261005,
#   'params': {'intensity_clay': 0.12568858095958857,
#    'intensity_sand': 0.1420373871165814}},
#  {'target': 0.9562978318385027,
#   'params': {'intensity_clay': 0.1272149398030033,
#    'intensity_sand': 0.1376376203791386}},
#  {'target': 0.9577078754294556,
#   'params': {'intensity_clay': 0.12784542952393374,
#    'intensity_sand': 0.13768748150481325}},
#  {'target': 0.9573644889713797,
#   'params': {'intensity_clay': 0.12609812210997154,
#    'intensity_sand': 0.14225456077221116}},
#  {'target': 0.9576157338359131,
#   'params': {'intensity_clay': 0.12837967228077315,
#    'intensity_sand': 0.13856009431487054}},
#  {'target': 0.9573736244302176,
#   'params': {'intensity_clay': 0.12832980054063123,
#    'intensity_sand': 0.1377126004625738}},
#  {'target': 0.9577575995467694,
#   'params': {'intensity_clay': 0.12908695994863756,
#    'intensity_sand': 0.1389310239522648}},
#  {'target': 0.9579675856017423,
#   'params': {'intensity_clay': 0.12904250353649016,
#    'intensity_sand': 0.14015272304877752}},
#  {'target': 0.957488236855299,
#   'params': {'intensity_clay': 0.12885290700710333,
#    'intensity_sand': 0.1385363848753217}},
#  {'target': 0.9434400023006004,
#   'params': {'intensity_clay': 0.12229820155939024,
#    'intensity_sand': 0.13799552908221033}},
#  {'target': 0.9575967486171487,
#   'params': {'intensity_clay': 0.1292881184177114,
#    'intensity_sand': 0.13976847185602712}},
#  {'target': 0.9567686299545852,
#   'params': {'intensity_clay': 0.12941500975652825,
#    'intensity_sand': 0.1392945007865072}},
#  {'target': 0.9571734725946768,
#   'params': {'intensity_clay': 0.1257085987368121,
#    'intensity_sand': 0.14251019360215494}},
#  {'target': 0.9579647083905167,
#   'params': {'intensity_clay': 0.129496494609366,
#    'intensity_sand': 0.14024228967147798}},
#  {'target': 0.9573625381319615,
#   'params': {'intensity_clay': 0.1285662129113417,
#    'intensity_sand': 0.13811813030064865}},
#  {'target': 0.9570238128101424,
#   'params': {'intensity_clay': 0.12928131624346476,
#    'intensity_sand': 0.14060920478165445}},
#  {'target': 0.9505676254398531,
#   'params': {'intensity_clay': 0.1297871889642558,
#    'intensity_sand': 0.1398313764034533}},
#  {'target': 0.9559866617409817,
#   'params': {'intensity_clay': 0.1252453526241368,
#    'intensity_sand': 0.14228256395716454}},
#  {'target': 0.9555019875652643,
#   'params': {'intensity_clay': 0.12627237220332826,
#    'intensity_sand': 0.1377226571304082}},
#  {'target': 0.9461798722523151,
#   'params': {'intensity_clay': 0.12805597879080097,
#    'intensity_sand': 0.137245536515869}},
#  {'target': 0.9582348465014513,
#   'params': {'intensity_clay': 0.12889997143246587,
#    'intensity_sand': 0.1377646703295741}},
#  {'target': 0.9506789352064317,
#   'params': {'intensity_clay': 0.12977192130411933,
#    'intensity_sand': 0.14064950187382488}},
#  {'target': 0.9411073569133235,
#   'params': {'intensity_clay': 0.1267504827114406,
#    'intensity_sand': 0.13722533824643432}},
#  {'target': 0.956429031689407,
#   'params': {'intensity_clay': 0.1290078154267942,
#    'intensity_sand': 0.14112100504597289}},
#  {'target': 0.9572970546032755,
#   'params': {'intensity_clay': 0.12914221853152363,
#    'intensity_sand': 0.13811227628935271}},
#  {'target': 0.9568883639638038,
#   'params': {'intensity_clay': 0.1261772604585289,
#    'intensity_sand': 0.14274478198288598}},
#  {'target': 0.9558878166775429,
#   'params': {'intensity_clay': 0.1265919626438092,
#    'intensity_sand': 0.14243411873542636}},
#  {'target': 0.9498336705012519,
#   'params': {'intensity_clay': 0.12930169476311698,
#    'intensity_sand': 0.14167164180222955}},
#  {'target': 0.9580337479016969,
#   'params': {'intensity_clay': 0.12942251156738963,
#    'intensity_sand': 0.13859867149960362}},
#  {'target': 0.9508564485962684,
#   'params': {'intensity_clay': 0.1296699213842561,
#    'intensity_sand': 0.1382055076352453}},
#  {'target': 0.9462951016230765,
#   'params': {'intensity_clay': 0.129185370029057,
#    'intensity_sand': 0.13743088805881756}},
#  {'target': 0.9359654366599379,
#   'params': {'intensity_clay': 0.12387104761120568,
#    'intensity_sand': 0.13730232318961638}},
#  {'target': 0.9569859232749881,
#   'params': {'intensity_clay': 0.1257209648693312,
#    'intensity_sand': 0.14304630906058463}},
#  {'target': 0.9575097671960284,
#   'params': {'intensity_clay': 0.12866819992720427,
#    'intensity_sand': 0.13783259722204635}},
#  {'target': 0.9564243260867443,
#   'params': {'intensity_clay': 0.1265585054562579,
#    'intensity_sand': 0.141895615464267}},
#  {'target': 0.9574246203334583,
#   'params': {'intensity_clay': 0.12955904907364932,
#    'intensity_sand': 0.13890778110582694}},
#  {'target': 0.9577336374453482,
#   'params': {'intensity_clay': 0.12616443125690177,
#    'intensity_sand': 0.14329852789211353}},
#  {'target': 0.9577299676491018,
#   'params': {'intensity_clay': 0.12658658293129887,
#    'intensity_sand': 0.1431257624169784}},
#  {'target': 0.9561197863462517,
#   'params': {'intensity_clay': 0.12576012439726958,
#    'intensity_sand': 0.1435813602013571}},
#  {'target': 0.9581669731547167,
#   'params': {'intensity_clay': 0.1265346079865807,
#    'intensity_sand': 0.14358576828261302}},
#  {'target': 0.9566917478863926,
#   'params': {'intensity_clay': 0.12621814885126764,
#    'intensity_sand': 0.14385161811932978}},
#  {'target': 0.9568628809780273,
#   'params': {'intensity_clay': 0.1252198880350011,
#    'intensity_sand': 0.14288945038373632}},
#  {'target': 0.9577414111091211,
#   'params': {'intensity_clay': 0.12696215033143532,
#    'intensity_sand': 0.14342688493709088}},
#  {'target': 0.9566688211629177,
#   'params': {'intensity_clay': 0.12706570127187874,
#    'intensity_sand': 0.1429657949033866}},
#  {'target': 0.9569650645948863,
#   'params': {'intensity_clay': 0.12573456967773894,
#    'intensity_sand': 0.14424796227538725}},
#  {'target': 0.9570280380044366,
#   'params': {'intensity_clay': 0.12517795563624987,
#    'intensity_sand': 0.1434144616826283}},
#  {'target': 0.9572138062715644,
#   'params': {'intensity_clay': 0.12684676715512977,
#    'intensity_sand': 0.14391720162328578}},
#  {'target': 0.956562630323818,
#   'params': {'intensity_clay': 0.12527742416146878,
#    'intensity_sand': 0.14397580043010386}},
#  {'target': 0.9523726096111197,
#   'params': {'intensity_clay': 0.12735319201661563,
#    'intensity_sand': 0.14373551613068905}},
#  {'target': 0.9565801950191093,
#   'params': {'intensity_clay': 0.12647277810322186,
#    'intensity_sand': 0.1443224166252785}},
#  {'target': 0.9565609232920824,
#   'params': {'intensity_clay': 0.1260221888448615,
#    'intensity_sand': 0.14468395620635324}},
#  {'target': 0.9551492961795274,
#   'params': {'intensity_clay': 0.12540832489053216,
#    'intensity_sand': 0.1446276030229534}},
#  {'target': 0.9455725156423405,
#   'params': {'intensity_clay': 0.12472839157157206,
#    'intensity_sand': 0.14315075235149471}},
#  {'target': 0.9564026678510431,
#   'params': {'intensity_clay': 0.12777675600125502,
#    'intensity_sand': 0.13793818881085912}},
#  {'target': 0.9568446062991307,
#   'params': {'intensity_clay': 0.12656366168370267,
#    'intensity_sand': 0.14489687822473593}},
#  {'target': 0.9572052150913682,
#   'params': {'intensity_clay': 0.1272149029147171,
#    'intensity_sand': 0.1423875631019561}},
#  {'target': 0.9439945383850491,
#   'params': {'intensity_clay': 0.126176086266876,
#    'intensity_sand': 0.14524306402770093}},
#  {'target': 0.9560570570976233,
#   'params': {'intensity_clay': 0.12688987586116882,
#    'intensity_sand': 0.14464448676160205}},
#  {'target': 0.9502160316125533,
#   'params': {'intensity_clay': 0.127586475497159,
#    'intensity_sand': 0.1426851173709093}},
#  {'target': 0.9441533589853482,
#   'params': {'intensity_clay': 0.12708132530036578,
#    'intensity_sand': 0.14514117415217895}},
#  {'target': 0.9561138240393244,
#   'params': {'intensity_clay': 0.12608764131032013,
#    'intensity_sand': 0.14433770938682655}},
#  {'target': 0.9566621843774844,
#   'params': {'intensity_clay': 0.14716588252457924,
#    'intensity_sand': 0.17499979194849336}},
#  {'target': 0.9564281986728331,
#   'params': {'intensity_clay': 0.1476367463329318,
#    'intensity_sand': 0.17481196805796972}},
#  {'target': 0.9564721041385761,
#   'params': {'intensity_clay': 0.1472157375495373,
#    'intensity_sand': 0.17449632462636286}},
#  {'target': 0.9566014876590121,
#   'params': {'intensity_clay': 0.14756255966230047,
#    'intensity_sand': 0.17536377586468052}},
#  {'target': 0.9581728429106997,
#   'params': {'intensity_clay': 0.12700748777541518,
#    'intensity_sand': 0.1420630795103234}},
#  {'target': 0.9296113396670669,
#   'params': {'intensity_clay': 0.14770198031551723,
#    'intensity_sand': 0.17421868829765386}},
#  {'target': 0.9565007030700226,
#   'params': {'intensity_clay': 0.14687022930950788,
#    'intensity_sand': 0.17459999979191218}},
#  {'target': 0.9506923267958701,
#   'params': {'intensity_clay': 0.12736063591634844,
#    'intensity_sand': 0.14202778899702856}},
#  {'target': 0.9574895188220299,
#   'params': {'intensity_clay': 0.1267323309212483,
#    'intensity_sand': 0.13800102756340868}},
#  {'target': 0.9561306542891057,
#   'params': {'intensity_clay': 0.1479422895438429,
#    'intensity_sand': 0.17515689901385545}},
#  {'target': 0.9565058988409528,
#   'params': {'intensity_clay': 0.14796974323226564,
#    'intensity_sand': 0.17580643670132173}},
#  {'target': 0.9573183814924809,
#   'params': {'intensity_clay': 0.1288876519385878,
#    'intensity_sand': 0.13802617918614696}},
#  {'target': 0.9547597656350947,
#   'params': {'intensity_clay': 0.126505714098264,
#    'intensity_sand': 0.14464292327802605}},
#  {'target': 0.9563549147732057,
#   'params': {'intensity_clay': 0.147461355803645,
#    'intensity_sand': 0.17598450594796203}},
#  {'target': 0.9563949513260189,
#   'params': {'intensity_clay': 0.14787900090496917,
#    'intensity_sand': 0.17635343098446668}},
#  {'target': 0.9567833161461015,
#   'params': {'intensity_clay': 0.14841637249460873,
#    'intensity_sand': 0.1761728454960647}},
#  {'target': 0.9572624049337868,
#   'params': {'intensity_clay': 0.12693963437980832,
#    'intensity_sand': 0.14233230830803045}},
#  {'target': 0.9566602297330417,
#   'params': {'intensity_clay': 0.1483642934320698,
#    'intensity_sand': 0.1766957686436185}},
#  {'target': 0.9564278149750711,
#   'params': {'intensity_clay': 0.14730643136657084,
#    'intensity_sand': 0.1765721118588173}},
#  {'target': 0.9493231569268032,
#   'params': {'intensity_clay': 0.14885907241355564,
#    'intensity_sand': 0.1764916292793117}},
#  {'target': 0.9563936180504674,
#   'params': {'intensity_clay': 0.14690464932673805,
#    'intensity_sand': 0.17618386574343994}},
#  {'target': 0.956501192355467,
#   'params': {'intensity_clay': 0.14698316979545148,
#    'intensity_sand': 0.1756384364034634}},
#  {'target': 0.9564779075757615,
#   'params': {'intensity_clay': 0.1267738176492372,
#    'intensity_sand': 0.14149664024278819}},
#  {'target': 0.9565571359453349,
#   'params': {'intensity_clay': 0.1464413512595208,
#    'intensity_sand': 0.17580587349377835}},
#  {'target': 0.956981738677094,
#   'params': {'intensity_clay': 0.1463397802816207,
#    'intensity_sand': 0.17635560894453986}},
#  {'target': 0.9567262255425453,
#   'params': {'intensity_clay': 0.1459349588772555,
#    'intensity_sand': 0.17605599001989716}},
#  {'target': 0.956019648010314,
#   'params': {'intensity_clay': 0.14790860563495212,
#    'intensity_sand': 0.17691772370565528}},
#  {'target': 0.9568268138676224,
#   'params': {'intensity_clay': 0.14594839295431605,
#    'intensity_sand': 0.1754999246594725}},
#  {'target': 0.9567373836749885,
#   'params': {'intensity_clay': 0.12543755855121574,
#    'intensity_sand': 0.14325353076851924}},
#  {'target': 0.9569386715018371,
#   'params': {'intensity_clay': 0.14673213779340302,
#    'intensity_sand': 0.1767523924298631}},
#  {'target': 0.9570344569685794,
#   'params': {'intensity_clay': 0.14619282371067616,
#    'intensity_sand': 0.17686043600328505}},
#  {'target': 0.9565656816706692,
#   'params': {'intensity_clay': 0.14713723077499796,
#    'intensity_sand': 0.17714181639125573}},
#  {'target': 0.9565774113932712,
#   'params': {'intensity_clay': 0.1465620237280712,
#    'intensity_sand': 0.1772488676294061}},
#  {'target': 0.9563051721970767,
#   'params': {'intensity_clay': 0.14644360622351343,
#    'intensity_sand': 0.17524462896740875}},
#  {'target': 0.9566856023107995,
#   'params': {'intensity_clay': 0.1459272845594039,
#    'intensity_sand': 0.1749466488311951}},
#  {'target': 0.9567622705461256,
#   'params': {'intensity_clay': 0.1475800807032474,
#    'intensity_sand': 0.1775277789889467}},
#  {'target': 0.9567684894212956,
#   'params': {'intensity_clay': 0.1459891523035385,
#    'intensity_sand': 0.17735807122493386}},
#  {'target': 0.9563810051735074,
#   'params': {'intensity_clay': 0.1470608549187317,
#    'intensity_sand': 0.17769837420723059}},
#  {'target': 0.9458230664052764,
#   'params': {'intensity_clay': 0.12475377690264355,
#    'intensity_sand': 0.14431279070640612}},
#  {'target': 0.9674300640134739,
#   'params': {'intensity_clay': 0.1475197789799075,
#    'intensity_sand': 0.1780596548260748}},
#  {'target': 0.9672827140415111,
#   'params': {'intensity_clay': 0.14761270733457746,
#    'intensity_sand': 0.1782219686906103}},
#  {'target': 0.9572028701506541,
#   'params': {'intensity_clay': 0.14554004645570742,
#    'intensity_sand': 0.17672704458051597}},
#  {'target': 0.9675673763713037,
#   'params': {'intensity_clay': 0.14742536107701065,
#    'intensity_sand': 0.1782188803427597}},
#  {'target': 0.9672226000652797,
#   'params': {'intensity_clay': 0.14777576040970378,
#    'intensity_sand': 0.17803644494575058}},
#  {'target': 0.9568378462573708,
#   'params': {'intensity_clay': 0.14526359660259383,
#    'intensity_sand': 0.1753114731243199}},
#  {'target': 0.9566573700316066,
#   'params': {'intensity_clay': 0.1452612541459816,
#    'intensity_sand': 0.17733859182928857}},
#  {'target': 0.967256892397121,
#   'params': {'intensity_clay': 0.14792804194761283,
#    'intensity_sand': 0.17821497371868367}},
#  {'target': 0.9674857156887513,
#   'params': {'intensity_clay': 0.1478305622960556,
#    'intensity_sand': 0.17844931428071142}},
#  {'target': 0.9671447164227397,
#   'params': {'intensity_clay': 0.14805329399605988,
#    'intensity_sand': 0.17846169137319842}},
#  {'target': 0.9667489282867506,
#   'params': {'intensity_clay': 0.14793374644272422,
#    'intensity_sand': 0.1786909576674477}},
#  {'target': 0.9674446238213311,
#   'params': {'intensity_clay': 0.14753469209312506,
#    'intensity_sand': 0.17858208663457564}},
#  {'target': 0.9680486717295226,
#   'params': {'intensity_clay': 0.14771264210741206,
#    'intensity_sand': 0.1786516113420013}},
#  {'target': 0.9678550487458167,
#   'params': {'intensity_clay': 0.14818376274915498,
#    'intensity_sand': 0.1780702623546974}},
#  {'target': 0.9676387568409797,
#   'params': {'intensity_clay': 0.1482778666185579,
#    'intensity_sand': 0.17826367078588967}},
#  {'target': 0.9568756331800808,
#   'params': {'intensity_clay': 0.14506689332897713,
#    'intensity_sand': 0.17609496028866606}},
#  {'target': 0.9677971394614644,
#   'params': {'intensity_clay': 0.14720591106344535,
#    'intensity_sand': 0.17846528212348536}},
#  {'target': 0.9674576716680352,
#   'params': {'intensity_clay': 0.14726645231925636,
#    'intensity_sand': 0.17874906533130028}},
#  {'target': 0.9678448765045496,
#   'params': {'intensity_clay': 0.14756365655792478,
#    'intensity_sand': 0.1788915799072371}},
#  {'target': 0.9567494508839754,
#   'params': {'intensity_clay': 0.1451771162034881,
#    'intensity_sand': 0.1744593024359105}},
#  {'target': 0.9675187605152256,
#   'params': {'intensity_clay': 0.14712829619020446,
#    'intensity_sand': 0.1782384917670369}},
#  {'target': 0.9674206397941955,
#   'params': {'intensity_clay': 0.14725779062030903,
#    'intensity_sand': 0.17831316304176273}},
#  {'target': 0.9678108966046562,
#   'params': {'intensity_clay': 0.14692544144148842,
#    'intensity_sand': 0.17851179139988402}},
#  {'target': 0.967421710591534,
#   'params': {'intensity_clay': 0.14685849053011538,
#    'intensity_sand': 0.17830385444225394}},
#  {'target': 0.9679667274359852,
#   'params': {'intensity_clay': 0.14730062948000955,
#    'intensity_sand': 0.1790858445394483}},
#  {'target': 0.9676895474972298,
#   'params': {'intensity_clay': 0.14848033621117615,
#    'intensity_sand': 0.17802482120348942}},
#  {'target': 0.9675920885011499,
#   'params': {'intensity_clay': 0.14754447615919775,
#    'intensity_sand': 0.17921227923490968}},
#  {'target': 0.9673086758512974,
#   'params': {'intensity_clay': 0.1478050893646175,
#    'intensity_sand': 0.179068281954758}},
#  {'target': 0.9674516091365026,
#   'params': {'intensity_clay': 0.14862805628090517,
#    'intensity_sand': 0.1782865489704529}},
#  {'target': 0.9664462575490078,
#   'params': {'intensity_clay': 0.1478565013952353,
#    'intensity_sand': 0.17942652871667306}},
#  {'target': 0.9674504377429822,
#   'params': {'intensity_clay': 0.1469771477140492,
#    'intensity_sand': 0.1789499912616579}},
#  {'target': 0.9670132749627508,
#   'params': {'intensity_clay': 0.14819586526387984,
#    'intensity_sand': 0.17917990006953793}},
#  {'target': 0.9678497697773641,
#   'params': {'intensity_clay': 0.14663131198607696,
#    'intensity_sand': 0.17872848531936172}},
#  {'target': 0.956698710342978,
#   'params': {'intensity_clay': 0.14825727042141482,
#    'intensity_sand': 0.17776307942833025}},
#  {'target': 0.9673506224738356,
#   'params': {'intensity_clay': 0.14715403795785367,
#    'intensity_sand': 0.17937534090960916}},
#  {'target': 0.9669503901095413,
#   'params': {'intensity_clay': 0.14842382598062742,
#    'intensity_sand': 0.1788041448564458}},
#  {'target': 0.9674645185777131,
#   'params': {'intensity_clay': 0.14744308484218763,
#    'intensity_sand': 0.17954109593890985}},
#  {'target': 0.9679843619006346,
#   'params': {'intensity_clay': 0.14663956085748242,
#    'intensity_sand': 0.17907121278363394}},
#  {'target': 0.9511051021035946,
#   'params': {'intensity_clay': 0.14878967425056333,
#    'intensity_sand': 0.17873471826489917}},
#  {'target': 0.9673193228989233,
#   'params': {'intensity_clay': 0.1471222893043654,
#    'intensity_sand': 0.17974896113729794}},
#  {'target': 0.9671142690506382,
#   'params': {'intensity_clay': 0.14677805062835625,
#    'intensity_sand': 0.1794605176301073}},
#  {'target': 0.9669997219383736,
#   'params': {'intensity_clay': 0.14634731554423136,
#    'intensity_sand': 0.1789242092376542}},
#  {'target': 0.9674226793354116,
#   'params': {'intensity_clay': 0.146398764902855,
#    'intensity_sand': 0.17849033565140326}},
#  {'target': 0.9675667555470867,
#   'params': {'intensity_clay': 0.14641685629547577,
#    'intensity_sand': 0.17932340622573045}},
#  {'target': 0.9669523064551283,
#   'params': {'intensity_clay': 0.14662691267197397,
#    'intensity_sand': 0.17847498733156175}},
#  {'target': 0.9678419134365163,
#   'params': {'intensity_clay': 0.1474715313168129,
#    'intensity_sand': 0.17991253793552836}},
#  {'target': 0.9673042068578956,
#   'params': {'intensity_clay': 0.14735058504860898,
#    'intensity_sand': 0.17929025539757706}},
#  {'target': 0.9675060701633909,
#   'params': {'intensity_clay': 0.14687337219127528,
#    'intensity_sand': 0.17921654499835415}},
#  {'target': 0.9630316287372608,
#   'params': {'intensity_clay': 0.14602319001620293,
#    'intensity_sand': 0.17926634519944712}},
#  {'target': 0.9670953883719743,
#   'params': {'intensity_clay': 0.1477459010122204,
#    'intensity_sand': 0.17981567782682523}},
#  {'target': 0.9676355803608517,
#   'params': {'intensity_clay': 0.14821788433608854,
#    'intensity_sand': 0.1797141376650499}},
#  {'target': 0.9673015285245758,
#   'params': {'intensity_clay': 0.14809761986450462,
#    'intensity_sand': 0.18004612185682187}},
#  {'target': 0.9673428420894207,
#   'params': {'intensity_clay': 0.147210818674415,
#    'intensity_sand': 0.1801754304644266}},
#  {'target': 0.9674971655188351,
#   'params': {'intensity_clay': 0.14763223177947615,
#    'intensity_sand': 0.18025214147960755}},
#  {'target': 0.9675506445656007,
#   'params': {'intensity_clay': 0.14671676099065828,
#    'intensity_sand': 0.17995762301241705}},
#  {'target': 0.967798602358948,
#   'params': {'intensity_clay': 0.14644063546173625,
#    'intensity_sand': 0.1797231023233893}},
#  {'target': 0.9637964064095801,
#   'params': {'intensity_clay': 0.14602018602322273,
#    'intensity_sand': 0.17857600125503148}},
#  {'target': 0.9675229933454548,
#   'params': {'intensity_clay': 0.14797927967863841,
#    'intensity_sand': 0.1804608595262638}},
#  {'target': 0.9676146363351471,
#   'params': {'intensity_clay': 0.14837335694834464,
#    'intensity_sand': 0.18034028097626476}},
#  {'target': 0.967437977874896,
#   'params': {'intensity_clay': 0.1484881251071468,
#    'intensity_sand': 0.1799780196814062}},
#  {'target': 0.9670817734716116,
#   'params': {'intensity_clay': 0.14630994209430775,
#    'intensity_sand': 0.17814436805118292}},
#  {'target': 0.9673542391466912,
#   'params': {'intensity_clay': 0.14752333826617764,
#    'intensity_sand': 0.1806315096695862}},
#  {'target': 0.9673745278772508,
#   'params': {'intensity_clay': 0.14850718453892847,
#    'intensity_sand': 0.17816958128997964}},
#  {'target': 0.9673494932659044,
#   'params': {'intensity_clay': 0.14788955104206153,
#    'intensity_sand': 0.1808403866743385}},
#  {'target': 0.9518819884157383,
#   'params': {'intensity_clay': 0.1488043548595775,
#    'intensity_sand': 0.17803136447911982}},
#  {'target': 0.9672060488438738,
#   'params': {'intensity_clay': 0.1475567198185279,
#    'intensity_sand': 0.1810289462564569}},
#  {'target': 0.9674229172637333,
#   'params': {'intensity_clay': 0.14829363529561482,
#    'intensity_sand': 0.18072323571503185}},
#  {'target': 0.9670276878683373,
#   'params': {'intensity_clay': 0.14843024760641432,
#    'intensity_sand': 0.17849051805174118}},
#  {'target': 0.9674893087237844,
#   'params': {'intensity_clay': 0.14709596404158615,
#    'intensity_sand': 0.18070476970226557}},
#  {'target': 0.9675916237900645,
#   'params': {'intensity_clay': 0.14806527971586345,
#    'intensity_sand': 0.18120125758029326}},
#  {'target': 0.9675840973836172,
#   'params': {'intensity_clay': 0.1484049681159667,
#    'intensity_sand': 0.18110771036762296}},
#  {'target': 0.9674857598719923,
#   'params': {'intensity_clay': 0.14724082240775313,
#    'intensity_sand': 0.18048882849326045}},
#  {'target': 0.9507039998604221,
#   'params': {'intensity_clay': 0.14871414726408874,
#    'intensity_sand': 0.18068248507821635}},
#  {'target': 0.96768583768896,
#   'params': {'intensity_clay': 0.14666622130965168,
#    'intensity_sand': 0.1797269275620072}},
#  {'target': 0.9673193635340455,
#   'params': {'intensity_clay': 0.14679354604549502,
#    'intensity_sand': 0.18041351279862236}},
#  {'target': 0.9672869196580918,
#   'params': {'intensity_clay': 0.14849208981781634,
#    'intensity_sand': 0.1795950636652373}},
#  {'target': 0.9676452472002983,
#   'params': {'intensity_clay': 0.14820362354671834,
#    'intensity_sand': 0.18032442303536358}},
#  {'target': 0.9673895039156565,
#   'params': {'intensity_clay': 0.14715571242688316,
#    'intensity_sand': 0.18113352633619598}},
#  {'target': 0.9677297555575589,
#   'params': {'intensity_clay': 0.1465511073939406,
#    'intensity_sand': 0.17815635341856922}},
#  {'target': 0.9667732807902225,
#   'params': {'intensity_clay': 0.14637330172701257,
#    'intensity_sand': 0.18020151801897688}},
#  {'target': 0.9664819992078216,
#   'params': {'intensity_clay': 0.1483407509335359,
#    'intensity_sand': 0.181427801803817}},
#  {'target': 0.9673965389456377,
#   'params': {'intensity_clay': 0.14745961421189366,
#    'intensity_sand': 0.18145957038208574}},
#  {'target': 0.9673091715163167,
#   'params': {'intensity_clay': 0.14707585721359362,
#    'intensity_sand': 0.1815621211625458}},
#  {'target': 0.9682787242614909,
#   'params': {'intensity_clay': 0.14734724595911333,
#    'intensity_sand': 0.18186908227975054}},
#  {'target': 0.9675044466979549,
#   'params': {'intensity_clay': 0.14773110474449494,
#    'intensity_sand': 0.18182283059066504}},
#  {'target': 0.9672322851181892,
#   'params': {'intensity_clay': 0.14666252086262613,
#    'intensity_sand': 0.18093326832024217}},
#  {'target': 0.9676457176039941,
#   'params': {'intensity_clay': 0.14747701689864437,
#    'intensity_sand': 0.18172826425223776}},
#  {'target': 0.9676654660525547,
#   'params': {'intensity_clay': 0.1464747965374846,
#    'intensity_sand': 0.1799609897646968}},
#  {'target': 0.9672725941992613,
#   'params': {'intensity_clay': 0.14823278233727877,
#    'intensity_sand': 0.17886095540721694}},
#  {'target': 0.9676879708107341,
#   'params': {'intensity_clay': 0.14642688759724867,
#    'intensity_sand': 0.18064873043819726}},
#  {'target': 0.9634977787170138,
#   'params': {'intensity_clay': 0.14621596698579511,
#    'intensity_sand': 0.1810512115454889}},
#  {'target': 0.967711257567006,
#   'params': {'intensity_clay': 0.14755697271283771,
#    'intensity_sand': 0.18219799096268055}},
#  {'target': 0.9680393629550719,
#   'params': {'intensity_clay': 0.1475319742426901,
#    'intensity_sand': 0.18199342946343203}},
#  {'target': 0.9681047414843964,
#   'params': {'intensity_clay': 0.14712153479824258,
#    'intensity_sand': 0.1822018565268056}},
#  {'target': 0.9627185274664141,
#   'params': {'intensity_clay': 0.14594885404083652,
#    'intensity_sand': 0.17997869828235905}},
#  {'target': 0.9682137599184452,
#   'params': {'intensity_clay': 0.14690209766799306,
#    'intensity_sand': 0.1819355417934685}},
#  {'target': 0.9632815241866592,
#   'params': {'intensity_clay': 0.1459965395411656,
#    'intensity_sand': 0.18056620352640765}},
#  {'target': 0.9682883850424775,
#   'params': {'intensity_clay': 0.14805315103377198,
#    'intensity_sand': 0.18215991398567719}},
#  {'target': 0.9675690307329132,
#   'params': {'intensity_clay': 0.1478435617749997,
#    'intensity_sand': 0.18211977531055543}},
#  {'target': 0.9673758428677156,
#   'params': {'intensity_clay': 0.14818947966075588,
#    'intensity_sand': 0.18096911640225627}},
#  {'target': 0.9678747863664628,
#   'params': {'intensity_clay': 0.1480516276728686,
#    'intensity_sand': 0.1825319021589524}},
#  {'target': 0.9679846870597006,
#   'params': {'intensity_clay': 0.1483970738110002,
#    'intensity_sand': 0.18236671689021686}},
#  {'target': 0.967640965646628,
#   'params': {'intensity_clay': 0.14662703908932329,
#    'intensity_sand': 0.181568079700539}},
#  {'target': 0.9684728384045157,
#   'params': {'intensity_clay': 0.14714216796489776,
#    'intensity_sand': 0.18199253437807764}},
#  {'target': 0.9680915349121045,
#   'params': {'intensity_clay': 0.14645209808215992,
#    'intensity_sand': 0.1820126540143494}},
#  {'target': 0.9680159747642172,
#   'params': {'intensity_clay': 0.1484214958299744,
#    'intensity_sand': 0.18200863699395942}},
#  {'target': 0.9678123977087603,
#   'params': {'intensity_clay': 0.1482639404362352,
#    'intensity_sand': 0.18222073231211178}},
#  {'target': 0.9627796148212754,
#   'params': {'intensity_clay': 0.14621279327188985,
#    'intensity_sand': 0.1817473923018449}},
#  {'target': 0.9547696274908732,
#   'params': {'intensity_clay': 0.14882232822534208,
#    'intensity_sand': 0.18218050820819615}},
#  {'target': 0.9681577412510316,
#   'params': {'intensity_clay': 0.14834171410847377,
#    'intensity_sand': 0.1827532874198235}},
#  {'target': 0.967672897618404,
#   'params': {'intensity_clay': 0.14747125236226546,
#    'intensity_sand': 0.18274652203081695}},
#  {'target': 0.967905979458205,
#   'params': {'intensity_clay': 0.1466493204754702,
#    'intensity_sand': 0.18236392053178394}},
#  {'target': 0.967934072740501,
#   'params': {'intensity_clay': 0.14789609622507777,
#    'intensity_sand': 0.18298016357813726}},
#  {'target': 0.9680388982488398,
#   'params': {'intensity_clay': 0.1474767541411836,
#    'intensity_sand': 0.1832006879485295}},
#  {'target': 0.9682147785336176,
#   'params': {'intensity_clay': 0.14702960091863698,
#    'intensity_sand': 0.18291632787586903}},
#  {'target': 0.9680157449047627,
#   'params': {'intensity_clay': 0.14705481412035448,
#    'intensity_sand': 0.18331619890515513}},
#  {'target': 0.967897590314793,
#   'params': {'intensity_clay': 0.14661137536263205,
#    'intensity_sand': 0.18304030679867142}},
#  {'target': 0.9677483658768038,
#   'params': {'intensity_clay': 0.14793542225249345,
#    'intensity_sand': 0.1834475257254987}},
#  {'target': 0.9680736264189715,
#   'params': {'intensity_clay': 0.14628146940709644,
#    'intensity_sand': 0.1826277002561742}},
#  {'target': 0.9680112427267803,
#   'params': {'intensity_clay': 0.1474919019639058,
#    'intensity_sand': 0.18365034786815693}},
#  {'target': 0.9677861892560207,
#   'params': {'intensity_clay': 0.14701582251805498,
#    'intensity_sand': 0.18378841494862494}},
#  {'target': 0.9665777244117855,
#   'params': {'intensity_clay': 0.14681034065310453,
#    'intensity_sand': 0.1812865893859977}},
#  {'target': 0.9679738676612946,
#   'params': {'intensity_clay': 0.14736113450389654,
#    'intensity_sand': 0.18410227148836042}},
#  {'target': 0.967756795979075,
#   'params': {'intensity_clay': 0.14817659634528077,
#    'intensity_sand': 0.18186462848766774}},
#  {'target': 0.9676187247277939,
#   'params': {'intensity_clay': 0.1465644539822183,
#    'intensity_sand': 0.18352908341838814}},
#  {'target': 0.9678949547130244,
#   'params': {'intensity_clay': 0.14690116769161715,
#    'intensity_sand': 0.18425343564883945}},
#  {'target': 0.9626290249426166,
#   'params': {'intensity_clay': 0.14614369199373667,
#    'intensity_sand': 0.18312956545711342}},
#  {'target': 0.9677679390466952,
#   'params': {'intensity_clay': 0.14784504647252575,
#    'intensity_sand': 0.1839547232504832}},
#  {'target': 0.9678048780127528,
#   'params': {'intensity_clay': 0.14726295335011186,
#    'intensity_sand': 0.18456455041759723}},
#  {'target': 0.9676761688905974,
#   'params': {'intensity_clay': 0.14837128072037925,
#    'intensity_sand': 0.1832791930470494}},
#  {'target': 0.9682761007684649,
#   'params': {'intensity_clay': 0.1466298964054149,
#    'intensity_sand': 0.18271283563908852}},
#  {'target': 0.967384265916183,
#   'params': {'intensity_clay': 0.14771237918447944,
#    'intensity_sand': 0.18443813106110055}},
#  {'target': 0.9679518498296293,
#   'params': {'intensity_clay': 0.146556078033156,
#    'intensity_sand': 0.18397986026558868}},
#  {'target': 0.9679142372103603,
#   'params': {'intensity_clay': 0.14834719631255186,
#    'intensity_sand': 0.18380572194991368}},
#  {'target': 0.9682288060229026,
#   'params': {'intensity_clay': 0.147584596373296,
#    'intensity_sand': 0.18495859603591763}},
#  {'target': 0.9676137568375826,
#   'params': {'intensity_clay': 0.1482713911292819,
#    'intensity_sand': 0.18432247196168722}},
#  {'target': 0.9557705302877669,
#   'params': {'intensity_clay': 0.14824479080358266,
#    'intensity_sand': 0.18543320254627793}},
#  {'target': 0.9551552186003422,
#   'params': {'intensity_clay': 0.14872326410730244,
#    'intensity_sand': 0.18409025281654276}},
#  {'target': 0.9679690677398375,
#   'params': {'intensity_clay': 0.14812606533707964,
#    'intensity_sand': 0.18405797441361613}},
#  {'target': 0.9677320948655331,
#   'params': {'intensity_clay': 0.14727676774460455,
#    'intensity_sand': 0.1834873695936919}},
#  {'target': 0.9676276500636836,
#   'params': {'intensity_clay': 0.14717097915019878,
#    'intensity_sand': 0.1850287642765382}},
#  {'target': 0.9674523189746848,
#   'params': {'intensity_clay': 0.14666499167258024,
#    'intensity_sand': 0.18468830006543505}},
#  {'target': 0.9677452598282953,
#   'params': {'intensity_clay': 0.14663339803320516,
#    'intensity_sand': 0.18520366680840938}},
#  {'target': 0.9559872020456526,
#   'params': {'intensity_clay': 0.146978281084459,
#    'intensity_sand': 0.18552721378507067}},
#  {'target': 0.9678589185082278,
#   'params': {'intensity_clay': 0.14664953593840163,
#    'intensity_sand': 0.18187194436282125}},
#  {'target': 0.9677218687646814,
#   'params': {'intensity_clay': 0.14818002135250571,
#    'intensity_sand': 0.18364412658444035}},
#  {'target': 0.9676744829469955,
#   'params': {'intensity_clay': 0.1463088382661437,
#    'intensity_sand': 0.18232370505399098}},
#  {'target': 0.9676861485707179,
#   'params': {'intensity_clay': 0.1463092649301267,
#    'intensity_sand': 0.1850204800648072}},
#  {'target': 0.962665995422332,
#   'params': {'intensity_clay': 0.14618369917867569,
#    'intensity_sand': 0.1843822827867413}},
#  {'target': 0.9674439120349035,
#   'params': {'intensity_clay': 0.14673062030327913,
#    'intensity_sand': 0.18379066905301142}},
# ...
#    'intensity_sand': 0.1979431513464651}},
#  {'target': 0.9810474268741374,
#   'params': {'intensity_clay': 0.14805741511593953,
#    'intensity_sand': 0.19740215528650618}},
#  {'target': 0.9810929663380462,
#   'params': {'intensity_clay': 0.14726728190302327,
#    'intensity_sand': 0.19814699243086603}},
#  {'target': 0.980923016070777,
#   'params': {'intensity_clay': 0.14844520487861504,
#    'intensity_sand': 0.19745766631647774}},
#  {'target': 0.9810280695973701,
#   'params': {'intensity_clay': 0.14691914774021558,
#    'intensity_sand': 0.1975799373916165}},
#  {'target': 0.9807744075546072,
#   'params': {'intensity_clay': 0.14826416054976047,
#    'intensity_sand': 0.19689316823905822}},
#  {'target': 0.9807127968309983,
#   'params': {'intensity_clay': 0.14745836539584095,
#    'intensity_sand': 0.19703615096590169}},
#  {'target': 0.9811260310197959,
#   'params': {'intensity_clay': 0.14788828994681733,
#    'intensity_sand': 0.1969844004849796}},
#  {'target': 0.9809928119515796,
#   'params': {'intensity_clay': 0.1472459851134549,
#    'intensity_sand': 0.19740277558542507}},
#  {'target': 0.9804294406453056,
#   'params': {'intensity_clay': 0.14777790522532944,
#    'intensity_sand': 0.19642851237391085}},
#  {'target': 0.9810069999269677,
#   'params': {'intensity_clay': 0.1468978311587691,
#    'intensity_sand': 0.1968328709729231}},
#  {'target': 0.9813230282847529,
#   'params': {'intensity_clay': 0.14691000483761169,
#    'intensity_sand': 0.1971663122529042}},
#  {'target': 0.9809392726302254,
#   'params': {'intensity_clay': 0.14796557668799862, 'intensity_sand': 0.2}},
#  {'target': 0.980717445399411,
#   'params': {'intensity_clay': 0.1473073049543226,
#    'intensity_sand': 0.19655760194165073}},
#  {'target': 0.980683927065673,
#   'params': {'intensity_clay': 0.14634407202575173,
#    'intensity_sand': 0.19717120109774292}},
#  {'target': 0.9809476533061592,
#   'params': {'intensity_clay': 0.14635632741247626,
#    'intensity_sand': 0.19772579910469454}},
#  {'target': 0.9810409315689335,
#   'params': {'intensity_clay': 0.14654223189302806,
#    'intensity_sand': 0.19744050603750063}},
#  {'target': 0.978212708109286,
#   'params': {'intensity_clay': 0.1489210354167916,
#    'intensity_sand': 0.19700688446664819}},
#  {'target': 0.9808354939107604,
#   'params': {'intensity_clay': 0.14641575247415467,
#    'intensity_sand': 0.1964370125687678}},
#  {'target': 0.9535206715044663,
#   'params': {'intensity_clay': 0.1468880275288406,
#    'intensity_sand': 0.19610117740408933}},
#  {'target': 0.9810042907272912,
#   'params': {'intensity_clay': 0.14754848146810012,
#    'intensity_sand': 0.1966856202899578}},
#  {'target': 0.9660189737129574,
#   'params': {'intensity_clay': 0.14621046050594433,
#    'intensity_sand': 0.1966438962864641}},
#  {'target': 0.980915748127932,
#   'params': {'intensity_clay': 0.148394440159204,
#    'intensity_sand': 0.1963475567551124}},
#  {'target': 0.966853227264463,
#   'params': {'intensity_clay': 0.1462224721213947,
#    'intensity_sand': 0.19747896977855361}},
#  {'target': 0.9805034425338485,
#   'params': {'intensity_clay': 0.1464938500538142,
#    'intensity_sand': 0.1979880172855074}},
#  {'target': 0.9805738408893636,
#   'params': {'intensity_clay': 0.14652066325788288,
#    'intensity_sand': 0.19776890302809322}},
#  {'target': 0.9812575415901983,
#   'params': {'intensity_clay': 0.14812793684580064,
#    'intensity_sand': 0.19653253326932724}},
#  {'target': 0.9809863385317514,
#   'params': {'intensity_clay': 0.14840215691368583,
#    'intensity_sand': 0.19961501444137333}},
#  {'target': 0.9814082127733462,
#   'params': {'intensity_clay': 0.14854946137531955, 'intensity_sand': 0.2}},
#  {'target': 0.9793489219600889,
#   'params': {'intensity_clay': 0.14893872495302513,
#    'intensity_sand': 0.19635965914768594}},
#  {'target': 0.9786873960427409,
#   'params': {'intensity_clay': 0.14895365579897574,
#    'intensity_sand': 0.19974699657669923}},
#  {'target': 0.9802964149296289,
#   'params': {'intensity_clay': 0.1482795260458675,
#    'intensity_sand': 0.19990168597075136}},
#  {'target': 0.9811435776975198,
#   'params': {'intensity_clay': 0.14848133407201755,
#    'intensity_sand': 0.19925369658302025}},
#  {'target': 0.9559968657861965,
#   'params': {'intensity_clay': 0.14871458046917052,
#    'intensity_sand': 0.195813917556562}},
#  {'target': 0.9804902283670135,
#   'params': {'intensity_clay': 0.14655480108019386,
#    'intensity_sand': 0.1970597137658507}},
#  {'target': 0.9787977696103642,
#   'params': {'intensity_clay': 0.14865259208936013,
#    'intensity_sand': 0.19658799955590794}},
#  {'target': 0.9810271466848922,
#   'params': {'intensity_clay': 0.1463124704582756,
#    'intensity_sand': 0.19794275984171492}},
#  {'target': 0.9786819561517129,
#   'params': {'intensity_clay': 0.14940008647758302,
#    'intensity_sand': 0.19661721707256216}},
#  {'target': 0.9787443705663219,
#   'params': {'intensity_clay': 0.1495319097271836,
#    'intensity_sand': 0.19741551799426443}},
#  {'target': 0.9806544157017812,
#   'params': {'intensity_clay': 0.14720453488014953,
#    'intensity_sand': 0.19679957620703925}},
#  {'target': 0.9787893673045113,
#   'params': {'intensity_clay': 0.15007250789164142,
#    'intensity_sand': 0.19709148242665409}},
#  {'target': 0.9784765850712451,
#   'params': {'intensity_clay': 0.1501229134571878,
#    'intensity_sand': 0.19772259028529535}},
#  {'target': 0.9786746791585754,
#   'params': {'intensity_clay': 0.15067791857636642,
#    'intensity_sand': 0.19738947422072414}},
#  {'target': 0.9805652461411118,
#   'params': {'intensity_clay': 0.14647640577454485,
#    'intensity_sand': 0.19720176009984675}},
#  {'target': 0.9786244235442098,
#   'params': {'intensity_clay': 0.15069022182234335,
#    'intensity_sand': 0.1967431443348292}},
#  {'target': 0.9819002117293791,
#   'params': {'intensity_clay': 0.1512625260403397,
#    'intensity_sand': 0.19699451064454587}},
#  {'target': 0.9819474370637742,
#   'params': {'intensity_clay': 0.1513928880710078,
#    'intensity_sand': 0.19741469231476094}},
#  {'target': 0.9827271541614626,
#   'params': {'intensity_clay': 0.15171581785729787,
#    'intensity_sand': 0.19713518313310177}},
#  {'target': 0.9808841793188195,
#   'params': {'intensity_clay': 0.14659954997235905,
#    'intensity_sand': 0.1985912373705565}},
#  {'target': 0.9823312517365347,
#   'params': {'intensity_clay': 0.15167671363493762,
#    'intensity_sand': 0.1966299943526112}},
#  {'target': 0.9815466321075602,
#   'params': {'intensity_clay': 0.15210962814392923,
#    'intensity_sand': 0.19678047693711856}},
#  {'target': 0.9814284219139231,
#   'params': {'intensity_clay': 0.15206011967828062,
#    'intensity_sand': 0.19755260260172647}},
#  {'target': 0.9829219135338642,
#   'params': {'intensity_clay': 0.15164389290621616,
#    'intensity_sand': 0.19792826812688075}},
#  {'target': 0.981658396941949,
#   'params': {'intensity_clay': 0.151708980225389,
#    'intensity_sand': 0.1976489482854328}},
#  {'target': 0.9588611407973817,
#   'params': {'intensity_clay': 0.15201137958090385,
#    'intensity_sand': 0.19614129260703675}},
#  {'target': 0.9816893452874887,
#   'params': {'intensity_clay': 0.15204329162058156,
#    'intensity_sand': 0.19818859483125945}},
#  {'target': 0.9819318567095694,
#   'params': {'intensity_clay': 0.1511263767558976,
#    'intensity_sand': 0.19812188140771794}},
#  {'target': 0.9819001694509542,
#   'params': {'intensity_clay': 0.15175759231574243,
#    'intensity_sand': 0.1968595319913069}},
#  {'target': 0.9819822817288135,
#   'params': {'intensity_clay': 0.15231540960091036,
#    'intensity_sand': 0.19712102944742596}},
#  {'target': 0.9818736389226367,
#   'params': {'intensity_clay': 0.15264210822733784,
#    'intensity_sand': 0.19788416324122957}},
#  {'target': 0.9823322567856153,
#   'params': {'intensity_clay': 0.15289466972408378,
#    'intensity_sand': 0.1974183463564861}},
#  {'target': 0.9821060690910598,
#   'params': {'intensity_clay': 0.15320749317077706,
#    'intensity_sand': 0.19781990514723358}},
#  {'target': 0.9818999294071745,
#   'params': {'intensity_clay': 0.15154072010585698,
#    'intensity_sand': 0.1983850233558062}},
#  {'target': 0.982338030473702,
#   'params': {'intensity_clay': 0.15295451589081752,
#    'intensity_sand': 0.19838538134521982}},
#  {'target': 0.982012933994391,
#   'params': {'intensity_clay': 0.15142274068101416,
#    'intensity_sand': 0.1980621821006506}},
#  {'target': 0.9822177983701763,
#   'params': {'intensity_clay': 0.15244525064866532,
#    'intensity_sand': 0.19873904777397802}},
#  {'target': 0.9819491890431713,
#   'params': {'intensity_clay': 0.15192129187974807,
#    'intensity_sand': 0.19887413676424656}},
#  {'target': 0.9790030669533883,
#   'params': {'intensity_clay': 0.15071266523878948,
#    'intensity_sand': 0.1986056452627335}},
#  {'target': 0.9828111781494583,
#   'params': {'intensity_clay': 0.15296046820909767,
#    'intensity_sand': 0.19901395012313242}},
#  {'target': 0.9826744984769216,
#   'params': {'intensity_clay': 0.15339152017697075,
#    'intensity_sand': 0.1987016171529234}},
#  {'target': 0.9818905751480788,
#   'params': {'intensity_clay': 0.15343463582674996,
#    'intensity_sand': 0.19827994490439727}},
#  {'target': 0.9817185914296975,
#   'params': {'intensity_clay': 0.15240245537096886,
#    'intensity_sand': 0.19927612771370304}},
#  {'target': 0.982555403507352,
#   'params': {'intensity_clay': 0.15308373228480027,
#    'intensity_sand': 0.19870958126967941}},
#  {'target': 0.9815038186099164,
#   'params': {'intensity_clay': 0.1533827894994568,
#    'intensity_sand': 0.1993544745169971}},
#  {'target': 0.9812497681830802,
#   'params': {'intensity_clay': 0.15388882427442968,
#    'intensity_sand': 0.1989976802020381}},
#  {'target': 0.9814501965962479,
#   'params': {'intensity_clay': 0.15133759163032723,
#    'intensity_sand': 0.19907929384813666}},
#  {'target': 0.9824007823782875,
#   'params': {'intensity_clay': 0.15177942059489571,
#    'intensity_sand': 0.1994731912020573}},
#  {'target': 0.9808564289153675,
#   'params': {'intensity_clay': 0.15350525053625402,
#    'intensity_sand': 0.19728699259363117}},
#  {'target': 0.9817533966689767,
#   'params': {'intensity_clay': 0.15302447672920225,
#    'intensity_sand': 0.19694572887652617}},
#  {'target': 0.9814292197474576,
#   'params': {'intensity_clay': 0.1513238823943794,
#    'intensity_sand': 0.1966063817075783}},
#  {'target': 0.9813144852541257,
#   'params': {'intensity_clay': 0.15400600480988713,
#    'intensity_sand': 0.1996311774680481}},
#  {'target': 0.978090384893641,
#   'params': {'intensity_clay': 0.1506605287683829,
#    'intensity_sand': 0.19805434042633158}},
#  {'target': 0.9827805187091009,
#   'params': {'intensity_clay': 0.15278271153390785,
#    'intensity_sand': 0.1998674569688752}},
#  {'target': 0.981496137232532,
#   'params': {'intensity_clay': 0.15225094298264516,
#    'intensity_sand': 0.19991347534824497}},
#  {'target': 0.9813036229557534,
#   'params': {'intensity_clay': 0.1545080992942411,
#    'intensity_sand': 0.19932272134705933}},
#  {'target': 0.9811094310925327,
#   'params': {'intensity_clay': 0.1542377347922656,
#    'intensity_sand': 0.1983755623094794}},
#  {'target': 0.979085341031008,
#   'params': {'intensity_clay': 0.15335434858288666, 'intensity_sand': 0.2}},
#  {'target': 0.9809417454104966,
#   'params': {'intensity_clay': 0.1545184704426401,
#    'intensity_sand': 0.1988096230300043}},
#  {'target': 0.9825018558918147,
#   'params': {'intensity_clay': 0.1528673388364862,
#    'intensity_sand': 0.1995198703866903}},
#  {'target': 0.9815838807950359,
#   'params': {'intensity_clay': 0.15129249913202247,
#    'intensity_sand': 0.1998235034779982}},
#  {'target': 0.9785401194383946,
#   'params': {'intensity_clay': 0.15169428689279316, 'intensity_sand': 0.2}},
#  {'target': 0.9787886103327528,
#   'params': {'intensity_clay': 0.15078114960492686,
#    'intensity_sand': 0.19949572142567482}},
#  {'target': 0.9810696616474143,
#   'params': {'intensity_clay': 0.15517726829158268,
#    'intensity_sand': 0.19911881062958722}},
#  {'target': 0.9813569099013124,
#   'params': {'intensity_clay': 0.1539037489962496,
#    'intensity_sand': 0.19783255569178282}},
#  {'target': 0.9813240159715728,
#   'params': {'intensity_clay': 0.15508690588560284,
#    'intensity_sand': 0.19843499074679222}},
#  {'target': 0.9814558291674785,
#   'params': {'intensity_clay': 0.1546488970898989,
#    'intensity_sand': 0.19785776617005835}},
#  {'target': 0.9784155794707429,
#   'params': {'intensity_clay': 0.14965202672278358,
#    'intensity_sand': 0.1984088019569421}},
#  {'target': 0.9813714965738628,
#   'params': {'intensity_clay': 0.15569674351757148,
#    'intensity_sand': 0.19870249249542613}},
#  {'target': 0.9800789751309837,
#   'params': {'intensity_clay': 0.15583483546599797,
#    'intensity_sand': 0.19929005429759536}},
#  {'target': 0.9812879287969172,
#   'params': {'intensity_clay': 0.15432101346211902,
#    'intensity_sand': 0.19727253768165265}},
#  {'target': 0.9820598788932681,
#   'params': {'intensity_clay': 0.15481781057422475,
#    'intensity_sand': 0.19993492774085106}},
#  {'target': 0.9833903403188938,
#   'params': {'intensity_clay': 0.15136575051625442,
#    'intensity_sand': 0.19949723355343568}},
#  {'target': 0.9813879934779687,
#   'params': {'intensity_clay': 0.15533282126039633,
#    'intensity_sand': 0.1997772236928487}},
#  {'target': 0.9812717856713538,
#   'params': {'intensity_clay': 0.1538809708859036,
#    'intensity_sand': 0.19666872601123764}},
#  {'target': 0.9812181673529492,
#   'params': {'intensity_clay': 0.15456711008515736,
#    'intensity_sand': 0.19663662571985235}},
#  {'target': 0.9810639537024871,
#   'params': {'intensity_clay': 0.15509604260749946,
#    'intensity_sand': 0.19728485978759858}},
#  {'target': 0.9782345835645595,
#   'params': {'intensity_clay': 0.14991870006825422,
#    'intensity_sand': 0.1991464577234448}},
#  {'target': 0.950731899569009,
#   'params': {'intensity_clay': 0.1542058054167094,
#    'intensity_sand': 0.1960700792026814}},
#  {'target': 0.9816066491724449,
#   'params': {'intensity_clay': 0.15466319555640468,
#    'intensity_sand': 0.1969469221175895}},
#  {'target': 0.9811402332420618,
#   'params': {'intensity_clay': 0.15533218490852602,
#    'intensity_sand': 0.1967255306989151}},
#  {'target': 0.981405827072801,
#   'params': {'intensity_clay': 0.15558125840347117,
#    'intensity_sand': 0.19786300161738823}},
#  {'target': 0.9801589926502828,
#   'params': {'intensity_clay': 0.1562270102759632,
#    'intensity_sand': 0.19822676151459098}},
#  {'target': 0.9794164396784115,
#   'params': {'intensity_clay': 0.15585425851344684,
#    'intensity_sand': 0.19722989829179902}},
#  {'target': 0.9813532041758263,
#   'params': {'intensity_clay': 0.15495034678863248,
#    'intensity_sand': 0.19959114352311952}},
#  {'target': 0.9828968384633997,
#   'params': {'intensity_clay': 0.1560183977095092, 'intensity_sand': 0.2}},
#  {'target': 0.98031500774284,
#   'params': {'intensity_clay': 0.15650122105182865,
#    'intensity_sand': 0.19969949733686293}},
#  {'target': 0.9798128046307778,
#   'params': {'intensity_clay': 0.1564806805063363,
#    'intensity_sand': 0.19889856220578503}},
#  {'target': 0.977490692627421,
#   'params': {'intensity_clay': 0.15432976400956078, 'intensity_sand': 0.2}},
#  {'target': 0.9809208291535408,
#   'params': {'intensity_clay': 0.15604490285272948,
#    'intensity_sand': 0.1964424565370153}},
#  {'target': 0.9509835238860149,
#   'params': {'intensity_clay': 0.15567050201678304,
#    'intensity_sand': 0.19613416165725492}},
#  {'target': 0.9809692947339121,
#   'params': {'intensity_clay': 0.1551485392143806,
#    'intensity_sand': 0.1979428438864136}},
#  {'target': 0.9805918932019179,
#   'params': {'intensity_clay': 0.15630000273369177,
#    'intensity_sand': 0.19668913558266463}},
#  {'target': 0.9797684052231213,
#   'params': {'intensity_clay': 0.15711677427695656,
#    'intensity_sand': 0.19847496852638516}},
#  {'target': 0.9803184557672063,
#   'params': {'intensity_clay': 0.1569290551925763,
#    'intensity_sand': 0.19790256950169685}},
#  {'target': 0.981613331343926,
#   'params': {'intensity_clay': 0.15407451630537639,
#    'intensity_sand': 0.19692589172118122}},
#  {'target': 0.9794673095158903,
#   'params': {'intensity_clay': 0.1572348003580204,
#    'intensity_sand': 0.1992979108105754}},
#  {'target': 0.9794307211495674,
#   'params': {'intensity_clay': 0.15765606900507576,
#    'intensity_sand': 0.1979270355616376}},
#  ...]

# %%
df = pd.DataFrame.from_dict(tmp)
df
# Out:
#         target                                             params
# 0     0.913094  {'intensity_clay': 0.18944241392257222, 'inten...
# 1     0.907984  {'intensity_clay': 0.07758782175156417, 'inten...
# 2     0.950794  {'intensity_clay': 0.135158754362253, 'intensi...
# 3     0.915443  {'intensity_clay': 0.19467717796034328, 'inten...
# 4     0.915150  {'intensity_clay': 0.1623359956300868, 'intens...
# ...        ...                                                ...
# 1005  0.980147  {'intensity_clay': 0.1572038379895528, 'intens...
# 1006  0.977823  {'intensity_clay': 0.15817636693972864, 'inten...
# 1007  0.980702  {'intensity_clay': 0.1573726133661395, 'intens...
# 1008  0.983479  {'intensity_clay': 0.15743762897400385, 'inten...
# 1009  0.980583  {'intensity_clay': 0.1579381374516523, 'intens...
#
# [1010 rows x 2 columns]

# %%
df.iloc[0,1]
# Out:
# {'intensity_clay': 0.18944241392257222, 'intensity_sand': 0.0974563331872679}

# %%
df.iloc[0,1].keys()
# Out:
# dict_keys(['intensity_clay', 'intensity_sand'])

# %%
df.iloc[0,1].values()
# Out:
# dict_values([0.18944241392257222, 0.0974563331872679])

# %%
df.iloc[0,1].get('intensity_clay')
# Out:
# 0.18944241392257222

# %%
plt.plot(df['target']),plt.ylim([0.9,1])
# Out:
# ([<matplotlib.lines.Line2D at 0x220800ed550>], (0.9, 1.0))
